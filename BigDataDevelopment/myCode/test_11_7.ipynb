# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Python Spark Session").getOrCreate()
df = spark.read.csv("file:///D:/code/python/BigDataDevelopment/Lesson03/data/test.csv", header=True)
df.show()
# Out:
# +------+---+------+
# |  name|age|height|
# +------+---+------+
# |  Jonh| 22|  1.80|
# |Hughes| 34|  1.96|
# |  Mary| 27|  1.56|
# +------+---+------+
